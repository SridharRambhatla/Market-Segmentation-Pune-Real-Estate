# %%
import pandas as pd

# %%
fin = pd.read_csv('fin2.csv')

# %%
fin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16242 entries, 0 to 16241
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   bedroom         16242 non-null  int64
#  1   bathrooms       16242 non-null  int64
#  2   area            16242 non-null  float64
#  3   furnishing      16242 non-null  object
#  4   avalable_for    16242 non-null  object
#  5   floor_number    16242 non-null  int64
#  6   facing          16242 non-null  object
#  7   floor_type      16242 non-null  object
#  8   gate_community  16242 non-null  object
#  9   corner_pro      16242 non-null  object
#  10  parking         16242 non-null  int64
#  11  aggDur          16242 non-null  int64
#  12  noticeDur       16242 non-null  int64
#  13  powerbackup     16242 non-null  int64
#  14  propertyage     16242 non-null  object
#  15  no_room         16242 non-null  int64
#  16  pooja_room      16242 non-null  int64
# ...

# %%
arcol = fin[['area','Locality']]
arcol.head()
# Out:
#      area        Locality
# 0  1050.0   Pingale Wasti
# 1     0.0   Pingale Wasti
# 2   760.0         Wagholi
# 3  1050.0         Wagholi
# 4     0.0       Mahalunge

# %%
un = list(arcol.Locality.unique())

# %%
len(un)
# Out:
# 1133

# %%
res={}
for i in range(len(arcol)):
    if arcol.Locality[i] not in res:
        res[arcol.Locality[i]] = [arcol.area[i]]
    else:
         res[arcol.Locality[i]].append(arcol.area[i])

# %%
for k,v in res.items():
    print(k,v)
# Out:
#  Pingale Wasti [1050.0, 0.0, 540.0, 901.65, 800.0, 900.0, 320.0, 650.0, 750.0, 0.0, 450.0, 50.76, 0.0, 620.0, 1475.0]
# ...

# %%
len(res)
# Out:
# 1133

# %%
from functools import reduce
  
def Average(lst):
    return reduce(lambda a, b: a + b, lst) // len(lst)

# %%
des ={}
for k,v in res.items():
    des[k]=Average(v)

# %%
for k,v in des.items():
    print(k,v)
# Out:
#  Pingale Wasti 567.0
#  Wagholi 548.0
#  Mahalunge 505.0
#  Wanowrie 637.0
#  Uruli Devachi 307.0
#  Baner 743.0
#  Baner-Sus 667.0
#  Pashan-Sus Road 1001.0
#  Kharadi 654.0
#  Magarpatta 583.0
#  Bibwewadi Kondhwa Road 527.0
#  Aundh 624.0
#  Hinjewadi 537.0
#  Bibwewadi 393.0
#  Bhumkar Nagar 450.0
#  Pimpri Chinchwad 455.0
#  Katraj Kondhwa Road 612.0
#  Bhukum 534.0
#  Anand Nagar 301.0
#  Wakad 578.0
#  Yewalewadi 323.0
#  Bhugaon 528.0
#  Ambegaon Bk 482.0
#  Moshi 982.0
#  Pashan 565.0
#  Pune 322.0
#  Hadapsar 489.0
#  Manjri BK 360.0
#  Lohegaon 459.0
#  Wanwadi 575.0
#  Chinchwad 509.0
#  Keshav Nagar 498.0
#  Laxmi-Narayan Nagar 475.0
#  Somwar Peth 322.0
#  Ambegaon Budruk 478.0
#  Lullanagar 1025.0
#  Mhada Colony 486.0
#  Shivtirth Nagar 585.0
#  Ambegaon Pathar 343.0
#  Bhosari 525.0
#  Ashoka Nagar 739.0
#  Punawale 512.0
#  PIMPLE GURAV 425.0
#  Vadgaon Sheri 415.0
#  Kalyani Nagar 832.0
#  Chikhali 480.0
#  Thergaon 557.0
#  Keshav Nagar mundhwa 740.0
# ...

# %%
len(des)
# Out:
# 1133

# %%
def val(k,v):
    for i in range(len(v)):
        if v[i] == 0.0:
            v[i] = des[k]
    return v

# %%
for k,v in res.items():
    res[k] = val(k,v)

# %%
for k,v in res.items():
    print(k,v)
# Out:
#  Pingale Wasti [1050.0, 567.0, 540.0, 901.65, 800.0, 900.0, 320.0, 650.0, 750.0, 567.0, 450.0, 50.76, 567.0, 620.0, 1475.0]
# ...

# %%
df = pd.DataFrame(list(des.items()),columns = ['Locality','area'])

# %%
df
# Out:
#                                     Locality   area
# 0                              Pingale Wasti  567.0
# 1                                    Wagholi  548.0
# 2                                  Mahalunge  505.0
# 3                                   Wanowrie  637.0
# 4                              Uruli Devachi  307.0
# ...                                      ...    ...
# 1128                              lane no. 1  540.0
# 1129                        Padmavati mandir  540.0
# 1130                            kaspatewasti  960.0
# 1131                Marungi road Laxmi Chowk  550.0
# 1132   Unfurnishedp. To ThUnfurnishedte Lawn    0.0
#
# [1133 rows x 2 columns]

# %%
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'

# %%
for i in range(len(df)):
    for j in range(len(arcol)):
        if (df.Locality[i] == arcol.Locality[j]) & (arcol.area[j] == 0.0):
            arcol.area[j]=df.area[i]

# %%
print("Count of students with physics marks greater than 11 is->",
      arcol[arcol['area'] == 0].count())
# Out:
# Count of students with physics marks greater than 11 is-> area        209
# Locality    209
# dtype: int64

# %%
pes={}
for i in range(len(arcol)):
    if arcol.Locality[i] not in pes:
        pes[arcol.Locality[i]] = [arcol.area[i]]
    else:
         pes[arcol.Locality[i]].append(arcol.area[i])

# %%
for k,v in pes.items():
    print(k,v)
# Out:
#  Pingale Wasti [1050.0, 567.0, 540.0, 901.65, 800.0, 900.0, 320.0, 650.0, 750.0, 567.0, 450.0, 50.76, 567.0, 620.0, 1475.0]
# ...

# %%
print("Count of students with physics marks greater than 11 is->",
      arcol[arcol['area'] == 0].count())
# Out:
# Count of students with physics marks greater than 11 is-> area        5982
# Locality    5982
# dtype: int64

# %%
for i in range(len(df)):
    arcol['area'] = np.where((df.Locality[i] ) & (<filter 2>) , <new value>, df['column_name'])

# %%
fin3 =pd.merge(fin, arcol, left_index=True, right_index=True)

# %%
fin3.head(10)
# Out:
#    bedroom  bathrooms  area_x     furnishing                   avalable_for  \
# 0        2          2  1050.0    Unfurnished                            All
# 1        2          2     0.0  Semifurnished                            All
# 2        2          2   760.0    Unfurnished                            All
# 3        2          2  1050.0  Semifurnished                            All
# 4        3          3     0.0  Semifurnished                            All
# 5        2          2   900.0  Semifurnished                            All
# 6        1          1   628.0      Furnished                    Family Only
# 7        3          3  1100.0      Furnished                    Family Only
# 8        2          2   668.0  Semifurnished  Family , Bachelors (Men Only)
# 9        1          1   605.0  Semifurnished                    Family Only
#
#    floor_number        facing         floor_type gate_community corner_pro  \
# ...

# %%
fin3 = fin3.drop(['Locality_x','area_x'], axis = 1)

# %%
fin3.head(10)
# Out:
#    bedroom  bathrooms     furnishing                   avalable_for  \
# 0        2          2    Unfurnished                            All
# 1        2          2  Semifurnished                            All
# 2        2          2    Unfurnished                            All
# 3        2          2  Semifurnished                            All
# 4        3          3  Semifurnished                            All
# 5        2          2  Semifurnished                            All
# 6        1          1      Furnished                    Family Only
# 7        3          3      Furnished                    Family Only
# 8        2          2  Semifurnished  Family , Bachelors (Men Only)
# 9        1          1  Semifurnished                    Family Only
#
#    floor_number        facing         floor_type gate_community corner_pro  \
# 0             5          West             Marble            Yes         No
# ...

# %%
fin3 = fin3.drop(['corner_pro'], axis = 1)

# %%
fin3.columns
# Out:
# Index(['bedroom', 'bathrooms', 'furnishing', 'avalable_for', 'floor_number',
#        'facing', 'floor_type', 'gate_community', 'parking', 'aggDur',
#        'noticeDur', 'powerbackup', 'prUnfurnishedertyage', 'no_room',
#        'pooja_room', 'study_room', 'servant_room', 'store_room', 'deposit_amt',
#        'rent', 'area', 'loc'],
#       dtype='object')

# %%
fin3.to_csv('fin34.csv', index=False)

# %%
fin34 = pd.read_csv('fin34.csv')

# %%
un1 = list(fin34.furnishing.unique())
fur = pd.DataFrame(un1, columns=['furnishing'])
fur
# Out:
#       furnishing
# 0    Unfurnished
# 1  Semifurnished
# 2      Furnished

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
labelencoder = LabelEncoder()

# %%
labelencoder = LabelEncoder()
fur['fur_Cat'] = labelencoder.fit_transform(fur['furnishing'])
fur
# Out:
#       furnishing  fur_Cat
# 0    Unfurnished        2
# 1  Semifurnished        1
# 2      Furnished        0

# %%
fin34['fur_cat']=labelencoder.fit_transform(fin34['furnishing'])
fin34.head(10)
# Out:
#    bedroom  bathrooms     furnishing                   avalable_for  \
# 0        2          2    Unfurnished                            All
# 1        2          2  Semifurnished                            All
# 2        2          2    Unfurnished                            All
# 3        2          2  Semifurnished                            All
# 4        3          3  Semifurnished                            All
# 5        2          2  Semifurnished                            All
# 6        1          1      Furnished                    Family Only
# 7        3          3      Furnished                    Family Only
# 8        2          2  Semifurnished  Family , Bachelors (Men Only)
# 9        1          1  Semifurnished                    Family Only
#
#    floor_number        facing         floor_type gate_community  parking  \
# 0             5          West             Marble            Yes        0
# ...

# %%
fin34.columns
# Out:
# Index(['bedroom', 'bathrooms', 'furnishing', 'avalable_for', 'floor_number',
#        'facing', 'floor_type', 'gate_community', 'parking', 'aggDur',
#        'noticeDur', 'powerbackup', 'prUnfurnishedertyage', 'no_room',
#        'pooja_room', 'study_room', 'servant_room', 'store_room', 'deposit_amt',
#        'rent', 'area', 'loc', 'fur_cat'],
#       dtype='object')

# %%
fin34['loc_cat']=labelencoder.fit_transform(fin34['loc'])
fin34.head(10)
# Out:
#    bedroom  bathrooms     furnishing                   avalable_for  \
# 0        2          2    Unfurnished                            All
# 1        2          2  Semifurnished                            All
# 2        2          2    Unfurnished                            All
# 3        2          2  Semifurnished                            All
# 4        3          3  Semifurnished                            All
# 5        2          2  Semifurnished                            All
# 6        1          1      Furnished                    Family Only
# 7        3          3      Furnished                    Family Only
# 8        2          2  Semifurnished  Family , Bachelors (Men Only)
# 9        1          1  Semifurnished                    Family Only
#
#    floor_number        facing         floor_type gate_community  parking  \
# 0             5          West             Marble            Yes        0
# ...

# %%
fin34 = fin34[fin34['loc']!='Pune']

# %%
print("Count of students with physics marks greater than 11 is->",
      fin34[fin34['loc'] == 'Pune'].count())
# Out:
# Count of students with physics marks greater than 11 is-> bedroom                 0
# bathrooms               0
# furnishing              0
# avalable_for            0
# floor_number            0
# facing                  0
# floor_type              0
# gate_community          0
# parking                 0
# aggDur                  0
# noticeDur               0
# powerbackup             0
# prUnfurnishedertyage    0
# no_room                 0
# pooja_room              0
# study_room              0
# servant_room            0
# store_room              0
# deposit_amt             0
# rent                    0
# area                    0
# loc                     0
# fur_cat                 0
# loc_cat                 0
# dtype: int64

# %%
fin34.to_csv('fin35.csv', index=False)

# %%
fin34['gc_ct']=labelencoder.fit_transform(fin34['gate_community'])
fin34.head(10)
# Out:
#    bedroom  bathrooms     furnishing                   avalable_for  \
# 0        2          2    Unfurnished                            All
# 1        2          2  Semifurnished                            All
# 2        2          2    Unfurnished                            All
# 3        2          2  Semifurnished                            All
# 4        3          3  Semifurnished                            All
# 5        2          2  Semifurnished                            All
# 6        1          1      Furnished                    Family Only
# 7        3          3      Furnished                    Family Only
# 8        2          2  Semifurnished  Family , Bachelors (Men Only)
# 9        1          1  Semifurnished                    Family Only
#
#    floor_number        facing         floor_type gate_community  parking  \
# 0             5          West             Marble            Yes        0
# ...

# %%
fin34 = fin34.drop(['gate_community'], axis = 1)
fin34.columns
# Out:
# Index(['bedroom', 'bathrooms', 'furnishing', 'avalable_for', 'floor_number',
#        'facing', 'floor_type', 'parking', 'aggDur', 'noticeDur', 'powerbackup',
#        'prUnfurnishedertyage', 'no_room', 'pooja_room', 'study_room',
#        'servant_room', 'store_room', 'deposit_amt', 'rent', 'area', 'loc',
#        'fur_cat', 'loc_cat', 'gc_ct'],
#       dtype='object')

# %%
fin34.powerbackup
# Out:
# 0        2
# 1        0
# 2        2
# 3        1
# 4        2
#         ..
# 16237    2
# 16238    0
# 16239    2
# 16240    0
# 16241    0
# Name: powerbackup, Length: 16242, dtype: int64

# %%
fin34['p_age']=labelencoder.fit_transform(fin34['prUnfurnishedertyage'])
fin34.head(10)
# Out:
#    bedroom  bathrooms     furnishing                   avalable_for  \
# 0        2          2    Unfurnished                            All
# 1        2          2  Semifurnished                            All
# 2        2          2    Unfurnished                            All
# 3        2          2  Semifurnished                            All
# 4        3          3  Semifurnished                            All
# 5        2          2  Semifurnished                            All
# 6        1          1      Furnished                    Family Only
# 7        3          3      Furnished                    Family Only
# 8        2          2  Semifurnished  Family , Bachelors (Men Only)
# 9        1          1  Semifurnished                    Family Only
#
#    floor_number        facing         floor_type  parking  aggDur  noticeDur  \
# 0             5          West             Marble        0      11          2
# ...

# %%
fin34.to_csv('fin36.csv', index=False)

# %%
import pandas as pd
fin = pd.read_csv('fin36.csv')

# %%
fin.head(5)
# Out:
#    bedroom  bathrooms     furnishing avalable_for  floor_number        facing  \
# 0        2          2    Unfurnished          All             5          West
# 1        2          2  Semifurnished          All             1  No Direction
# 2        2          2    Unfurnished          All             5          East
# 3        2          2  Semifurnished          All             2          West
# 4        3          3  Semifurnished          All             1    South-West
#
#      floor_type  parking  aggDur  noticeDur  ...  servant_room store_room  \
# 0        Marble        0      11          2  ...             0          0
# 1  Not provided        1       0          0  ...             0          0
# 2     Vitrified        2      11          1  ...             0          0
# 3  Not provided        1      24          1  ...             0          0
# 4     Vitrified        1      11          1  ...             0          0
#
# ...

# %%
fin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16242 entries, 0 to 16241
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   bedroom               16242 non-null  int64
#  1   bathrooms             16242 non-null  int64
#  2   furnishing            16242 non-null  object
#  3   avalable_for          16242 non-null  object
#  4   floor_number          16242 non-null  int64
#  5   facing                16242 non-null  object
#  6   floor_type            16242 non-null  object
#  7   parking               16242 non-null  int64
#  8   aggDur                16242 non-null  int64
#  9   noticeDur             16242 non-null  int64
#  10  powerbackup           16242 non-null  int64
#  11  prUnfurnishedertyage  16242 non-null  object
#  12  no_room               16242 non-null  int64
#  13  pooja_room            16242 non-null  int64
#  14  study_room            16242 non-null  int64
# ...

# %%
ov = [i for i in fin.columns if ((len(fin[i].unique()) > 2 ) and (len(fin[i].unique()) <= 25))]


print(ov, end = ' ')
('Number of ordinal features is', len(ov))
# Out:
# ['bedroom', 'bathrooms', 'furnishing', 'avalable_for', 'floor_number', 'facing', 'floor_type', 'parking', 'noticeDur', 'powerbackup', 'prUnfurnishedertyage', 'fur_cat', 'p_age']
# ('Number of ordinal features is', 13)

# %%
fin.groupby('bedroom').count()
print('before shape',fin.shape)
fin.drop(fin[fin['bedroom']>= 6].index, axis = 0, inplace = True)
print('after droping rows the shape is ', fin.shape)
# Out:
# before shape (16242, 25)
# after droping rows the shape is  (16233, 25)

# %%
type(ov)
# Out:
# list

# %%
import os #for file part
from math import * # for mathmatically relations & computation  
from scipy.stats import * # Stat testing
import numpy as np # array operations 
import re # working on text data 
import pandas as pd # dataframe operations
import matplotlib.pyplot as plt # visualisations
import seaborn as sns # Viz
# import geocoder # Geographical Data analysis
# import geopy # Geographical data
# # from geopy.geocoders import Nominatim  # Geographical data

# All machine leanring libraries
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.linear_model import LinearRegression, Ridge, ElasticNet, Lasso
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
un1 = list(fin.prUnfurnishedertyage.unique())
fur = pd.DataFrame(un1, columns=['AGE'])
fur
# Out:
#                   AGE
# 0    5 to 10 Year Old
# 1     1 to 5 Year Old
# 2     0 to 1 Year Old
# 3        10+ Year Old
# 4  Under Construction
# 5              NO age

# %%
fig, ax = plt.subplots(4,3, figsize = (28,38), sharey = False)
fig.tight_layout(pad= 3.0)
fig.subplots_adjust(top=0.95)

sns.set_style('white')
fig.suptitle('Ordinal Variable  vs Target Median', size = 30)
sns.barplot(ax= ax[0,0], data =fin , x = fin.groupby('bedroom').median().index, y =fin.groupby('bedroom').median().rent,palette= 'muted' )
ax[0,0].set_title('Number of Bedrooms', fontsize = 15)

sns.barplot(ax= ax[0,1], data =fin , x = fin.groupby('bathrooms').median().index, y =fin.groupby('bathrooms').median().rent,palette= 'muted' )
ax[0,1].set_title('Number of bathrooms', fontsize = 15)

sns.barplot(ax= ax[0,2], data =fin , x = fin.groupby('furnishing').median().index, y =fin.groupby('furnishing').median().rent,palette= 'muted' )
ax[0,2].set_title('Furnishsing', fontsize = 20)

sns.barplot(ax= ax[1,0], data =fin , x = fin.groupby('avalable_for').median().index, y =fin.groupby('avalable_for').median().rent,palette= 'muted' )
ax[1,0].set_title('Available for', fontsize = 15)

sns.barplot(ax= ax[1,1], data =fin , x = fin.groupby('floor_number').median().index, y =fin.groupby('floor_number').median().rent,palette= 'muted' )
ax[1,1].set_title('Floor Number', fontsize = 15)

sns.barplot(ax= ax[1,2], data =fin , x = fin.groupby('facing').median().index, y =fin.groupby('facing').median().rent,palette= 'muted' )
ax[1,2].set_title('', fontsize = 15)

sns.barplot(ax= ax[2,0], data =fin , x = fin.groupby('floor_type').median().index, y =fin.groupby('floor_type').median().rent,palette= 'muted' )
ax[2,0].set_title('Floor Type', fontsize = 15)

sns.barplot(ax= ax[2,1], data =fin , x = fin.groupby('parking').median().index, y =fin.groupby('parking').median().rent,palette= 'muted' )
ax[2,1].set_title('Count of Parking', fontsize = 15)

# sns.barplot(ax= ax[2,2], data =fin , x = fin.groupby('aggDur').median().index, y =fin.groupby('aggDur').median().rent,palette= 'muted' )
# ax[2,2].set_title('Agreement Duration', fontsize = 15)

sns.barplot(ax= ax[2,2], data =fin , x = fin.groupby('noticeDur').median().index, y =fin.groupby('noticeDur').median().rent,palette= 'muted' )
ax[2,2].set_title('Notice Duration', fontsize = 15)

sns.barplot(ax= ax[3,0], data =fin , x = fin.groupby('powerbackup').median().index, y =fin.groupby('powerbackup').median().rent,palette= 'muted' )
ax[3,0].set_title('Power Backup Facility', fontsize = 15)

sns.barplot(ax= ax[3,1], data =fin , x = fin.groupby('p_age').median().index, y =fin.groupby('p_age').median().rent,palette= 'muted' )
ax[3,1].set_title('Property Age', fontsize = 15)

fig.delaxes(ax[3][2])

fig.savefig('ordinal_variable.jpg', dpi = 100)

# %%
bv = [i  for i in fin.columns  if (len(fin[i].unique()) == 2)]
print(bv, end = ' ')
('Number of ordinal features is', len(bv))
# Out:
# ['no_room', 'pooja_room', 'study_room', 'servant_room', 'store_room', 'gc_ct']
# ('Number of ordinal features is', 6)

# %%
fig, ax = plt.subplots(2,3, figsize = (15,10), sharey = True)
fig.tight_layout(pad =4.0)
fig.subplots_adjust(top=0.95)

sns.set_style('white')
# fig.suptitle('Binary Variables- Counts', size = 10)
sns.barplot(ax= ax[0,0], data =fin , x = fin.gc_ct.value_counts().index, y = fin.gc_ct.value_counts().values,palette= 'muted' )
ax[0,0].set_title('Gate Facility', fontsize = 15)
sns.barplot(ax= ax[0,1], data =fin , x = fin.no_room.value_counts().index, y = fin.no_room.value_counts().values,palette= 'flare' )
ax[0,1].set_title('No other rooms',  fontsize = 15)
sns.barplot(ax= ax[0,2], data =fin , x = fin.pooja_room.value_counts().index, y = fin.pooja_room.value_counts().values,palette= 'ch:s=.25,rot=-.25' )
ax[0,2].set_title('Pooja/ Holy Room',  fontsize = 15)
sns.barplot(ax= ax[1,0], data =fin , x = fin.study_room.value_counts().index, y = fin.study_room.value_counts().values,palette= 'muted' )
ax[1,0].set_title('Study_Room',  fontsize = 15)

sns.barplot(ax= ax[1,1], data =fin , x = fin.servant_room.value_counts().index, y = fin.servant_room.value_counts().values,palette= 'flare' )
ax[1,1].set_title('Servent Room',  fontsize = 15)
sns.barplot(ax= ax[1,2], data =fin , x = fin.store_room.value_counts().index, y = fin.store_room.value_counts().values,palette= 'husl' )
ax[1,2].set_title('Store Room',  fontsize = 15)
# sns.barplot(ax=ax[1,2], x = fin.index, y = fin.rent)

fig.savefig('cn_variable.jpg', dpi = 100)

# %%
just_test = fin.describe().columns
only_file = [i for i in just_test  if i not in bv]

only_file
# Out:
# ['bedroom',
#  'bathrooms',
#  'floor_number',
#  'parking',
#  'aggDur',
#  'noticeDur',
#  'powerbackup',
#  'deposit_amt',
#  'rent',
#  'area',
#  'fur_cat',
#  'loc_cat',
#  'p_age']

# %%
fig, ax = plt.subplots(11,2, figsize = (20,30))
fig.tight_layout(pad = 4.0)
fig.subplots_adjust(top = 0.95)
fig.suptitle('Variable  Histplo & Box Plot', size = 30)
sns.kdeplot(ax= ax[0,0], data = fin, x = 'bedroom')
sns.boxplot(ax= ax[0,1], data = fin, x = 'bedroom')
sns.kdeplot(ax= ax[1,0], data = fin, x = 'bathrooms')
sns.boxplot(ax= ax[1,1], data = fin, x = 'bathrooms')
sns.kdeplot(ax= ax[2,0], data = fin, x = 'area')
sns.boxplot(ax= ax[2,1], data = fin, x = 'area')
sns.kdeplot(ax= ax[3,0], data = fin, x = 'parking')
sns.boxplot(ax= ax[3,1], data = fin, x = 'parking')
sns.kdeplot(ax= ax[4,0], data = fin, x = 'aggDur')
sns.boxplot(ax= ax[4,1], data = fin, x = 'aggDur')
sns.kdeplot(ax= ax[5,0], data = fin, x = 'noticeDur')
sns.boxplot(ax= ax[5,1], data = fin, x = 'noticeDur')
sns.kdeplot(ax= ax[6,0], data = fin, x = 'powerbackup')
sns.boxplot(ax= ax[6,1], data = fin, x = 'powerbackup')
# sns.kdeplot(ax= ax[7,0], data = fin, x = 'brok_amt')
# sns.boxplot(ax= ax[7,1], data = fin, x = 'brok_amt')
sns.kdeplot(ax= ax[8,0], data = fin, x = 'deposit_amt')
sns.boxplot(ax= ax[8,1], data = fin, x = 'deposit_amt')
# sns.kdeplot(ax= ax[9,0], data = fin, x = 'mnt_amt')
# sns.boxplot(ax= ax[9,1], data = fin, x = 'mnt_amt')
sns.kdeplot(ax= ax[10,0], data = fin, x = 'powerbackup')
sns.boxplot(ax= ax[10,1], data = fin, x = 'powerbackup')
sns.kdeplot(ax= ax[10,0], data = fin, x = 'fur_cat')
sns.boxplot(ax= ax[10,1], data = fin, x = 'fur_cat')
sns.kdeplot(ax= ax[10,0], data = fin, x = 'p_age')
sns.boxplot(ax= ax[10,1], data = fin, x = 'p_age')

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
import plotly.graph_objs as go
from plotly import tools
from plotly.subplots import make_subplots
import plotly.offline as py
fin = pd.read_csv('fin36.csv')

# %%
#y = rent, x = bedroom , [furnishing,facing]

# %%
fin.head()
# Out:
#    bedroom  bathrooms     furnishing avalable_for  floor_number        facing  \
# 0        2          2    Unfurnished          All             5          West
# 1        2          2  Semifurnished          All             1  No Direction
# 2        2          2    Unfurnished          All             5          East
# 3        2          2  Semifurnished          All             2          West
# 4        3          3  Semifurnished          All             1    South-West
#
#      floor_type  parking  aggDur  noticeDur  ...  servant_room store_room  \
# 0        Marble        0      11          2  ...             0          0
# 1  Not provided        1       0          0  ...             0          0
# 2     Vitrified        2      11          1  ...             0          0
# 3  Not provided        1      24          1  ...             0          0
# 4     Vitrified        1      11          1  ...             0          0
#
# ...

# %%
fin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16242 entries, 0 to 16241
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   bedroom               16242 non-null  int64
#  1   bathrooms             16242 non-null  int64
#  2   furnishing            16242 non-null  object
#  3   avalable_for          16242 non-null  object
#  4   floor_number          16242 non-null  int64
#  5   facing                16242 non-null  object
#  6   floor_type            16242 non-null  object
#  7   parking               16242 non-null  int64
#  8   aggDur                16242 non-null  int64
#  9   noticeDur             16242 non-null  int64
#  10  powerbackup           16242 non-null  int64
#  11  prUnfurnishedertyage  16242 non-null  object
#  12  no_room               16242 non-null  int64
#  13  pooja_room            16242 non-null  int64
#  14  study_room            16242 non-null  int64
# ...

# %%
z = fin[['bedroom','area','rent']]
z
# Out:
#        bedroom    area     rent
# 0            2  1050.0  20000.0
# 1            2   567.0  18500.0
# 2            2   760.0  14000.0
# 3            2  1050.0  21000.0
# 4            3   505.0  22999.0
# ...        ...     ...      ...
# 16237        2   750.0  15000.0
# 16238        2    95.0  11000.0
# 16239        3  2390.0  55000.0
# 16240        2   563.0  14000.0
# 16241        1   500.0  23000.0
#
# [16242 rows x 3 columns]

# %%
import seaborn as sns
# %matplotlib inline

sns.set(rc={'figure.figsize':(20,8)}, font_scale=1.5, style='whitegrid')


sns.boxplot(data=z);

# %%
q1 = fin.quantile(0.25)
q3 = fin.quantile(0.75)
IQR = q3-q1
IQR

fin = fin[~((fin) > (q3 + (1.5 * IQR))).any(axis=1)]

fin.head()
# Out:
#    bedroom  bathrooms     furnishing avalable_for  floor_number        facing  \
# 0        2          2    Unfurnished          All             5          West
# 1        2          2  Semifurnished          All             1  No Direction
# 3        2          2  Semifurnished          All             2          West
# 4        3          3  Semifurnished          All             1    South-West
# 5        2          2  Semifurnished          All             6  No Direction
#
#      floor_type  parking  aggDur  noticeDur  ...  servant_room store_room  \
# 0        Marble        0      11          2  ...             0          0
# 1  Not provided        1       0          0  ...             0          0
# 3  Not provided        1      24          1  ...             0          0
# 4     Vitrified        1      11          1  ...             0          0
# 5  Not provided        1       0          1  ...             0          0
#
# ...

# %%
import seaborn as sns
# %matplotlib inline

sns.set(rc={'figure.figsize':(30,8)}, font_scale=1.5, style='whitegrid')


sns.boxplot(data=fin);

# %%
fin.no_room
# Out:
# 0        1
# 1        1
# 3        1
# 4        0
# 5        1
#         ..
# 16234    1
# 16236    1
# 16237    0
# 16240    1
# 16241    1
# Name: no_room, Length: 12326, dtype: int64

# %%
v = fin[['fur_cat','bedroom','rent']]

# %%
v.boxplot()

# %%
q1 = v.quantile(0.25)
q3 = v.quantile(0.75)
IQR = q3-q1
IQR

v = v[~((v) > (q3 + (1.5 * IQR))).any(axis=1)]

# %%
v.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12198 entries, 0 to 16241
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   fur_cat  12198 non-null  int64
#  1   bedroom  12198 non-null  int64
#  2   rent     12198 non-null  float64
# dtypes: float64(1), int64(2)
# memory usage: 381.2 KB

# %%
import numpy as np
import pandas as pd 
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
import plotly.graph_objs as go
from plotly import tools
from plotly.subplots import make_subplots
import plotly.offline as py

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=3, random_state=0)
tsne_obj= tsne.fit_transform(v)

# %%
df = pd.DataFrame({'X':tsne_obj[:,0],
                        'Y':tsne_obj[:,1],
                        'z':tsne_obj[:,2]})
df.head()
# Out:
#            X          Y          z
# 0  13.798292   3.787312 -15.714556
# 1  -0.423569  16.027187   6.773090
# 2  -9.221457   4.663181 -20.285732
# 3  15.921151 -24.123558  -5.794712
# 4 -10.141714   0.296068  12.844571

# %%
sns.heatmap(df.corr(), annot=True)

# %%
WCSS = []
for i in range(1,11):
    model = KMeans(n_clusters = i,init = 'k-means++')
    model.fit(df)
    WCSS.append(model.inertia_)
fig = plt.figure(figsize = (7,7))
plt.plot(range(1,11),WCSS, linewidth=4, markersize=12,marker='o',color = 'green')
plt.xticks(np.arange(11))
plt.xlabel("Number of clusters")
plt.ylabel("WCSS")
plt.show()

# %%
model = KMeans(n_clusters = 5, init = "k-means++", max_iter = 300, n_init = 10, random_state = 0)
y_clusters = model.fit_predict(tsne_obj)

# %%
sns.countplot(y_clusters)
# Out:
# C:\Python38\Anaconda3\envs\py3-TF2.0\lib\site-packages\seaborn\_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
df['cls']=y_clusters
print(df.head(10))
# Out:
#            X          Y          z  cls
# 0  13.798292   3.787312 -15.714556    4
# 1  -0.423569  16.027187   6.773090    3
# 2  -9.221457   4.663181 -20.285732    4
# 3  15.921151 -24.123558  -5.794712    0
# 4 -10.141714   0.296068  12.844571    1
# 5  -1.173316   7.847948 -29.117682    4
# 6 -16.233494  -0.457695  23.687826    1
# 7  17.470930  10.260099  13.775169    0
# 8  11.611786  -3.727792   2.754450    0
# 9  -4.195647   6.468773  -0.702766    3

# %%
import plotly as py
import plotly.graph_objs as go

def calcKMean(i,X3):
  algorithm = (KMeans(n_clusters = i ,init='k-means++', n_init = 10 ,max_iter=300, 
                        tol=0.0001,  random_state= 111  , algorithm='elkan') )
  algorithm.fit(X3)
  labels3 = algorithm.labels_
  centroids3 = algorithm.cluster_centers_
  return labels3

def plot3d(data, titles, labels3):
  data['label3'] =  labels3
  trace1 = go.Scatter3d(
      x= data[titles[0]],
      y= data[titles[1]],
      z= data[titles[2]],
      mode='markers',
      marker=dict(
          color = data['label3'], 
          size= 5,
          line=dict(
              color= data['label3'],
              width= 12
          ),
          opacity=0.8
      )
  )
  data = [trace1]
  layout = go.Layout(
  #     margin=dict(
  #         l=0,
  #         r=0,
  #         b=0,
  #         t=0
  #     )
      title= 'Clusters',
      scene = dict(
              xaxis = dict(title  = titles[0]),
              yaxis = dict(title  = titles[1]),
              zaxis = dict(title  = titles[2])
          )
  )
  fig = go.Figure(data=data, layout=layout)
  py.offline.iplot(fig)

# %%
labels3 =calcKMean(5,df)
plot3d(df, ["X","Y","z"],labels3)
